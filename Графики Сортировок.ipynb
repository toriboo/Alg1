# %%
from sympy import *
from sympy.plotting import plot
n = Symbol('n')
T_best = n**2 + 12*n
T_average = 2.125*n**2 + 13*n
T_worst = 2.5*n**2 + 13.5*n
p = plot(T_best, T_average, T_worst, (n, 0, 10), show=False, legend=True,xlim = (0,10), ylim=(0,400), title = 'Selection sort')
p[0].label = 'Best Case'
p[1].label = 'Average Case'
p[2].label = 'Worst Case'
p.legend = True
p.show()

# %%
T_best = 8*n
T_average = 3*n**2+8*n - 8
T_worst = 12*n**2 - 8*n+8
p = plot(T_best, T_average, T_worst, (n, 0, 10), show=False, legend=True,xlim = (0,10), ylim=(0,1200), title = 'Insertion sort')
p[0].label = 'Best Case'
p[1].label = 'Average Case'
p[2].label = 'Worst Case'
p.legend = True
p.show()

# %%
T_best = 3*n-1
T_average = 3.75*n**2-2
T_worst = 5*n**2-3*n-2
p = plot(T_best, T_average, T_worst, (n, 0, 10), show=False, legend=True,xlim = (0,10), ylim=(0,600), title = 'Bubble sort')
p[0].label = 'Best Case'
p[1].label = 'Average Case'
p[2].label = 'Worst Case'
p.legend = True
p.show()

# %%
T_best = n+2*n*(log(n,2)) + 6*2**((log(n,2))-1)
T_average = n + 3.5*n*(log(n,2)) + 5.5*2**((log(n,2))-1)
T_worst = n + 5*n*log(n,2)+5*2**((log(n,2))-1)
p = plot(T_best, T_average, T_worst, show=False, legend=True,xlim = (0,10), ylim=(0,300), title = 'Merge sort')
p[0].label = 'Best Case'
p[1].label = 'Average Case'
p[2].label = 'Worst Case'
p.legend = True
p.show()

# %%
T_best = n +5.5*n*(log(n,2)) + 3*(log(n,2))
T_average = 6.5*n*(log(n,2))+n+ 1.5*(log(n,2))
T_worst = 2.5*n**2 + 5*n
p = plot(T_best, T_average, T_worst, show=False, legend=True,xlim = (0,10), ylim=(0,300), title = 'Quick sort')
p[0].label = 'Best Case'
p[1].label = 'Average Case'
p[2].label = 'Worst Case'
p.legend = True
p.show()

# %%
T_best = 13*log(n,2) + 13*n*(log(n,2)) + 7*n
T_average = 16.5*log(n,2) + 16.5*n*(log(n,2)) + 7*n
T_worst = 20*log(n,2) + 20*n*(log(n,2)) + 7*n
p = plot(T_best, T_average, T_worst, show=False, legend=True,xlim = (0,10), ylim=(0,1200), title = 'Heap sort')
p[0].label = 'Best Case'
p[1].label = 'Average Case'
p[2].label = 'Worst Case'
p.legend = True
p.show()

# %%
T_best = 4*n*log(n,2) + 4*n*((log(n,2))**2) + 16*n-16
T_average = 3*n*log(n,2) + 5*n*((log(n,2))**2) + 52*n -52*n**(1/2)
T_worst = 8*n*log(n,2)*(1+log(n,2))  + 36*n -40 + 4*n**2
p = plot(T_best, T_average, T_worst, show=False, legend=True,xlim = (0,10), ylim=(0,1200), title = 'Shell sort')
p[0].label = 'Best Case'
p[1].label = 'Average Case'
p[2].label = 'Worst Case'
p.legend = True
p.show()
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power

# %%
shell = 3*n*log(n,2) + 5*n*((log(n,2))**2) + 52*n -52*n**(1/2)
heap = 16.5*log(n,2) + 16.5*n*(log(n,2)) + 7*n
quick = 6.5*n*(log(n,2))+n+ 1.5*(log(n,2))
merge = n + 3.5*n*(log(n,2)) + 5.5*2**((log(n,2))-1)
bubble = 3.75*n**2-2
insertion = 3*n**2+8*n - 8
selection = 2.125*n**2 + 13*n
p = plot(shell,heap,quick,merge,bubble,insertion,selection,xlim = (0,10), ylim=(0,1200),show = False,title = 'All sort')
p[0].label = 'Shell sort'
p[1].label = 'Heap sort'
p[2].label = 'Quick sort'
p[3].label = 'Merge sort'
p[4].label = 'Bubble sort'
p[5].label = 'Insertion sort'
p[6].label = 'Selection sort'
p.legend = True
p.show()
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power

# %%
p = plot(bubble,insertion,selection, legend = True, xlim = (0,10), ylim=(0,400),show = False)
p[0].label = 'Bubble sort'
p[1].label = 'Insertion sort'
p[2].label = 'Selection sort'
p.legend = True
p.show()

# %%
p =plot(shell,heap,quick,merge, legend = True, xlim = (0,10), ylim=(0,1200), show = False)
p[0].label = 'Shell sort'
p[1].label = 'Heap sort'
p[2].label = 'Quick sort'
p[3].label = 'Merge sort'
p.legend = True
p.show()
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = Symbol('x')

# %%
f1 = exp(x) 
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.192, 1.455, 10.844,28.720,64.566,128.677,226.124,307.885,333.318,445.895])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 1 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'g', label='Регрессия')
    
    plt.legend()
    plt.show()

# %%
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.131,1.154,4.947,16.195,43.488,84.384,138.283,185.558,299.490,457.929])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'g', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.263,1.252,4.481,13.465,34.777,67.682,118.256,171.888,331.393,381.575])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'g', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.181,1.426,7.097,16.822,40.953,80.074,156.473,250.469,427.816,629.715])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'g', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.001,0.604,3.773,9.795,20.109,45.329,78.295,98.44,132.524,184.264])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'b', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.100,0.993,3.379,11.802,22.743,41.439,67.806,105.403,156.826,215.393])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'b', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.334,1.715,8.964,15.783,31.689,54.605,85.935,140.489,189.374,268.092])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'b', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.586,2.753,9.392,20.122,39.951,65.504,90.306,128.610,181.375,255.939])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'b', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.317,3.322,11.899,30.628,68.490,128.73,221.897,403.336,632.423,1716.129])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'orange', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.653,3.904,17.806,41.695,89.045,176.849,323.188,541.420,893.269,1615.442])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'orange', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([  0.002,2.428,8.856,28.804,70.185,134.814,247.803,399.204,600.869,876.259])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'orange', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([ 0.946,5.820,19.903,47.414,97.360,178.047,242.692,454.704,678.588,999.848])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'orange', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000, 14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([ 0.034,0.079,0.154,0.242,0.444,0.528,0.684,1.026,1.199,1.388])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,2 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'purple', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000, 14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([ 0.036,0.094,0.160,0.393,0.430,0.570,0.778,0.954,1.225,1.445])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,2 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'purple', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000, 14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.038,0.096,0.162,0.254,0.448,0.548,0.652,1.216,1.373,1.406])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,2 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'purple', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000, 14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.032,0.08,0.15,0.307,0.474,0.627,0.951,1.1929,1.516,1.816])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,2 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'purple', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.062,0.992,0.888,1.293,1.278,1.721,1.139,1.810,1.836])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,4)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'y', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.045,0.411,0.295,1.158,0.745,1.346,1.939,2.543,1.678,2.624])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,4)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'y', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.073,0.063,0.067,0.080,0.205,0.129,0.178,0.210,0.218,0.247])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,2)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'y', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.099,0.292,0.246,0.307,0.391,0.707,0.842,1.037,2.049,3.195])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,4)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'y', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.280,0.779,2.420,1.893,2.459,4.186,4.972,6.297,8.150,9.203])

    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'r',)
    
    plt.plot(x_range, regression_line(x_range), 'c', label='Регрессия')
    
    plt.legend()
    plt.show()
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])

    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'r',)
    
    plt.plot(x_range, regression_line(x_range), 'c', label='Регрессия')
    
    plt.legend()
    plt.show()

# %%
points_Y = np.array([0.221,0.407,0.939,2.299,2.691,3.855,4.744,5.926,7.152,9.411])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.204,0.434,0.937,1.898,2.687,3.376,4.707,6.103,6.836,9.801])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.148,0.494,0.745,1.274,1.715,2.217,3.389,3.493,4.216,5.173])
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])

    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,7)
    
    plt.scatter(points_X, points_Y, c='b')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'r', label='Регрессия')
    
    plt.legend()
    plt.show()

# %%
points_Y = np.array([0.001,0.172,0.308,0.438,0.806,1.211,2.052,1.642,2.330,2.291])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.001,0.257,0.374,0.775,1.268,1.953,3.532,2.637,3.105,4.012])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.001,0.192,0.251,0.456,0.575,0.935,1.578,2.426,3.323,3.904])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.001,0.381,0.839,1.277,2.416,3.153,3.021,4.045,5.062,6.113])
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])

    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,7)
    
    plt.scatter(points_X, points_Y, c='b')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'g', label='Регрессия')
    
    plt.legend()
    plt.show()

# %%
points_Y = np.array([0.004,0.114,0.318,0.338,0.620,0.686,0.989,1.205,1.711,1.847])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.001,0.147,0.283,0.282,0.575,0.885,1.126,1.420,1.979,2.081])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.002,0.106,0.225,0.336,0.972,0.949,1.005,1.317,1.665,2.1052])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.001,0.241,0.444,0.580,0.813,1.069,1.580,1.881,2.297,2.619])
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])

    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,20)
    
    plt.scatter(points_X, points_Y, c='b')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'orange', label='Регрессия')
    
    plt.legend()
    plt.show()

# %%
points_Y = np.array([0.012,0.654,1.042,2.374,3.994,4.975,6.323,7.854,10.940,12.108])
print_points_ands_function1(f1)

# %%
points_Y = np.array([2.300,0.550,1.022,1.794,2.150,2.639,4.177,5.725,6.753,8.086])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0,0.700,1.529,2.872,3.937,4.900,6.117,8.796,10.741,12.357])
print_points_ands_function1(f1)

# %%
points_Y = np.array([0.108,1.088,2.075,3.459,4.877,5.963,8.240,11.345,14.093,19.731])
print_points_ands_function1(f1)

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.032,0.08,0.15,0.307,0.474,0.627,0.951,1.1929,1.516,1.816])
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, )
    
    plt.plot(x_range, regression_line(x_range), 'b', label='Merge sort')
    
    plt.legend()

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.099,0.292,0.246,0.307,0.391,0.707,0.842,1.037,2.049,3.195])
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, )
    
    plt.plot(x_range, regression_line(x_range), 'g', label='Quick sort')
    
    plt.legend()

# %%
def print_points_ands_function3(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.148,0.494,0.745,1.274,1.715,2.217,3.389,3.493,4.216,5.173])
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, )
    
    plt.plot(x_range, regression_line(x_range), 'orange', label='Heap sort')
    
    plt.legend()

# %%
def print_points_ands_function4(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.001,0.381,0.839,1.277,2.416,3.153,3.021,4.045,5.062,6.113])
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, )
    
    plt.plot(x_range, regression_line(x_range), 'y', label='Shell_sort/shell')
    
    plt.legend()

# %%
def print_points_ands_function5(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.001,0.241,0.444,0.580,0.813,1.069,1.580,1.881,2.297,2.619])
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, )
    
    plt.plot(x_range, regression_line(x_range), 'purple', label='Shell_sort/hibbad')
    
    plt.legend()

# %%
def print_points_ands_function6(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([10000,14000, 18000, 22000, 26000, 30000,34000,38000,42000,46000])
    points_Y = np.array([0.108,1.088,2.075,3.459,4.877,5.963,8.240,11.345,14.093,19.731])
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 50000)
    plt.ylim(0,10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, )
    
    plt.plot(x_range, regression_line(x_range), 'c', label='Shell_sort/pratt')
    
    plt.legend()

# %%
print_points_ands_function1(f1)
print_points_ands_function2(f1)
print_points_ands_function3(f1)
print_points_ands_function4(f1)
print_points_ands_function5(f1)
print_points_ands_function6(f1)
plt.show()

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.181,1.426,7.097,16.822,40.953,80.074,156.473,250.469,427.816,629.715])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'g', label='Selection sort')
    
    plt.legend()

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([0.586,2.753,9.392,20.122,39.951,65.504,90.306,128.610,181.375,255.939])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'b', label='Insertion sort')
    
    plt.legend()

# %%
def print_points_ands_function3(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000])
    points_Y = np.array([ 0.946,5.820,19.903,47.414,97.360,178.047,242.692,454.704,678.588,999.848])
   
    
    coefficients = np.polyfit(points_X, points_Y, 2)  # 2 - степень полинома (линейная регрессия)
    regression_line = np.poly1d(coefficients)
    
    plt.xlim(0, 30000)
    plt.ylim(0,500 )
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b',)
    
    plt.plot(x_range, regression_line(x_range), 'orange', label='Bubble sort')
    
    plt.legend()

# %%
print_points_ands_function1(f1)
print_points_ands_function2(f1)
print_points_ands_function3(f1)

plt.show()
